# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(len(df))
# Out:
# 169

# %%
df.loc[0]["Duration"]
# Out:
# 60.0

# %%
i = 0
for i in range(len(df)):
    if df.loc[i]["Duration"] <= 150:
        print(df.loc[i])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64
# Duration     60.0
# Pulse       103.0
# Maxpulse    135.0
# Calories    340.0
# Name: 2, dtype: float64
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64
# Duration     45.0
# Pulse       117.0
# Maxpulse    148.0
# Calories    406.0
# Name: 4, dtype: float64
# Duration     60.0
# Pulse       102.0
# Maxpulse    127.0
# Calories    300.0
# Name: 5, dtype: float64
# Duration     60.0
# Pulse       110.0
# Maxpulse    136.0
# Calories    374.0
# Name: 6, dtype: float64
# Duration     45.0
# Pulse       104.0
# Maxpulse    134.0
# Calories    253.3
# Name: 7, dtype: float64
# Duration     30.0
# Pulse       109.0
# Maxpulse    133.0
# Calories    195.1
# Name: 8, dtype: float64
# Duration     60.0
# Pulse        98.0
# ...

# %%
i = 0
for i in range(len(df)):
    if df.loc[i]["Duration"] <= 150:
        #print(df.loc[i])
        if df.loc[i]["Duration"] >= 45:
            print(df.loc[i])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64
# Duration     60.0
# Pulse       103.0
# Maxpulse    135.0
# Calories    340.0
# Name: 2, dtype: float64
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64
# Duration     45.0
# Pulse       117.0
# Maxpulse    148.0
# Calories    406.0
# Name: 4, dtype: float64
# Duration     60.0
# Pulse       102.0
# Maxpulse    127.0
# Calories    300.0
# Name: 5, dtype: float64
# Duration     60.0
# Pulse       110.0
# Maxpulse    136.0
# Calories    374.0
# Name: 6, dtype: float64
# Duration     45.0
# Pulse       104.0
# Maxpulse    134.0
# Calories    253.3
# Name: 7, dtype: float64
# Duration     60.0
# Pulse        98.0
# Maxpulse    124.0
# Calories    269.0
# Name: 9, dtype: float64
# Duration     60.0
# Pulse       103.0
# ...

# %%
i = 0
for i in range(len(df)):
    if df.loc[i]["Duration"] >= 45 and df.loc[i]["Duration"] <= 150:
        print(df.loc[i])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64
# Duration     60.0
# Pulse       103.0
# Maxpulse    135.0
# Calories    340.0
# Name: 2, dtype: float64
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64
# Duration     45.0
# Pulse       117.0
# Maxpulse    148.0
# Calories    406.0
# Name: 4, dtype: float64
# Duration     60.0
# Pulse       102.0
# Maxpulse    127.0
# Calories    300.0
# Name: 5, dtype: float64
# Duration     60.0
# Pulse       110.0
# Maxpulse    136.0
# Calories    374.0
# Name: 6, dtype: float64
# Duration     45.0
# Pulse       104.0
# Maxpulse    134.0
# Calories    253.3
# Name: 7, dtype: float64
# Duration     60.0
# Pulse        98.0
# Maxpulse    124.0
# Calories    269.0
# Name: 9, dtype: float64
# Duration     60.0
# Pulse       103.0
# ...

# %%
i = 0
for i in range(len(df)):
    if df.loc[i]["Maxpulse"] > df.loc[i]["Calories"]:
        print(df.loc[i])
# Out:
# Duration     20.0
# Pulse       106.0
# Maxpulse    136.0
# Calories    110.4
# Name: 68, dtype: float64
# Duration     20.0
# Pulse        83.0
# Maxpulse    107.0
# Calories     50.3
# Name: 89, dtype: float64
# Duration     30.0
# Pulse        90.0
# Maxpulse    107.0
# Calories    105.3
# Name: 92, dtype: float64
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.5
# Name: 93, dtype: float64
# Duration     20.0
# Pulse       150.0
# Maxpulse    171.0
# Calories    127.4
# Name: 94, dtype: float64
# Duration     20.0
# Pulse        95.0
# Maxpulse    112.0
# Calories     77.7
# Name: 100, dtype: float64
# Duration     30.0
# Pulse        92.0
# Maxpulse    108.0
# Calories     92.7
# Name: 104, dtype: float64
# Duration     30.0
# Pulse        93.0
# Maxpulse    128.0
# Calories    124.0
# Name: 105, dtype: float64
# Duration     30.0
# Pulse        90.0
# Maxpulse    120.0
# Calories     86.2
# Name: 107, dtype: float64
# Duration     15.0
# ...
