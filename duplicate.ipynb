# %%
import pandas as pd

df = pd.read_csv("data2.csv")
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.duplicated()[0]
# Out:
# False

# %%
print(type(df.duplicated()[0]))
# Out:
# <class 'numpy.bool_'>

# %%
i = 0
for i in range(len(df)):
    if df.duplicated()[i] == False:
        print(df.loc[i])
# Out:
# Duration                     60
# Date        2020-12-01 00:00:00
# Pulse                       110
# Maxpulse                    130
# Calories                  409.1
# Name: 0, dtype: object
# Duration                     60
# Date        2020-12-02 00:00:00
# Pulse                       117
# Maxpulse                    145
# Calories                  479.0
# Name: 1, dtype: object
# Duration                     60
# Date        2020-12-03 00:00:00
# Pulse                       103
# Maxpulse                    135
# Calories                  340.0
# Name: 2, dtype: object
# Duration                     45
# Date        2020-12-04 00:00:00
# Pulse                       109
# Maxpulse                    175
# Calories                  282.4
# Name: 3, dtype: object
# Duration                     45
# Date        2020-12-05 00:00:00
# Pulse                       117
# Maxpulse                    148
# Calories                  406.0
# Name: 4, dtype: object
# ...
